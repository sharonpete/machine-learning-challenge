# %%
import sys
# !{sys.executable} -m pip install opencv-python
# Out:
# Collecting opencv-python
#   Downloading opencv_python-4.5.2.54-cp36-cp36m-win_amd64.whl (34.7 MB)
# Requirement already satisfied: numpy>=1.13.3 in c:\users\sharon\anaconda3\envs\pythondata\lib\site-packages (from opencv-python) (1.17.0)
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.5.2.54

# %%
import cv2
print(cv2.__version__)
# Out:
# 4.5.2

# %%
# Source... 
# https://stackoverflow.com/questions/60902599/how-to-import-opencv-on-jupyter-notebook#60902651
# https://stackoverflow.com/questions/57883178/how-to-install-cv2
